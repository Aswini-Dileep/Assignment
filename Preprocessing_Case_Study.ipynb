# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswini-Dileep/Assignment/blob/main/Preprocessing_Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Dataset Overview
# * Load the dataset House_Pricing.csv
# * Display basic information about the dataset using .info() and .describe() to understand the features, data types, and any initial insights into missing values.

# %%
df = pd.read_csv('/content/House_Pricing.csv')
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
df.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
df.size
# Out:
# 453873

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# # Duplicate Removal
# * Rows: Check for duplicate rows in the dataset, if any, and remove them.
# * Columns: Identify and drop duplicate columns, if any, based on their values.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Date House was Sold, Sale Price, No of Bedrooms, No of Bathrooms, Flat Area (in Sqft), Lot Area (in Sqft), No of Floors, Waterfront View, No of Times Visited, Condition of the House, Overall Grade, Area of the House from Basement (in Sqft), Basement Area (in Sqft), Age of House (in Years), Renovated Year, Zipcode, Latitude, Longitude, Living Area after Renovation (in Sqft), Lot Area after Renovation (in Sqft)]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.T[df.T.duplicated()].index
# Out:
# Index([], dtype='object')

# %% [markdown]
# # Handling Missing Values
# * Identify missing values in each column.
# * Handle missing values:
#   * For numerical columns, use imputation techniques like mean/median imputation.
#   * For categorical columns, fill with mode.
# * Document your approach for each feature with missing data.

# %%
df.isnull().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
df['No of Times Visited'].isnull().mean() * 100
# Out:
# np.float64(90.17258131680008)

# %%
df.drop(columns=['No of Times Visited'], inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Sale Price                                   4
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# Area of the House from Basement (in Sqft)    3
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# dtype: int64

# %%
df.dropna(subset=['Sale Price'], inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 226    8682281200       15 March 2016    479950.0               2
# 249    3797001895       15 April 2016    481000.0               3
# 275    4215100060       15 March 2016    365000.0               3
# 296    5468730030      14 August 2017    265000.0               3
# 321    2597650240     14 October 2017    520000.0               3
# 352     616000140     15 January 2016    315000.0               3
# 372    2231500030       15 March 2016    530000.0               4
# 402    6021501685       15 April 2016    352000.0               2
# 438    9528102772        14 July 2017    438000.0               2
# 449    4140090240    14 November 2017    520000.0               3
# 483    9169600135     14 October 2017    525000.0               3
# 509    3885805665        14 June 2017   1490000.0               4
# 586    7942601895      14 August 2017    640000.0               3
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
desired_columns = ['Flat Area (in Sqft)', 'Lot Area (in Sqft)', 'Area of the House from Basement (in Sqft)','Living Area after Renovation (in Sqft)','No of Bathrooms']

# Plot histograms for selected columns
df[desired_columns].hist(bins=30, figsize=(12, 6), edgecolor='black')
plt.tight_layout()
plt.show()

# %%
df['Flat Area (in Sqft)'].fillna(df['Flat Area (in Sqft)'].median(), inplace=True)
df['Lot Area (in Sqft)'].fillna(df['Lot Area (in Sqft)'].median(), inplace=True)
df['Area of the House from Basement (in Sqft)'].fillna(df['Area of the House from Basement (in Sqft)'].median(), inplace=True)
df['Living Area after Renovation (in Sqft)'].fillna(df['Living Area after Renovation (in Sqft)'].median(), inplace=True)
df['No of Bathrooms'].fillna(df['No of Bathrooms'].median(),inplace=True)
# Out:
# /tmp/ipython-input-1025246023.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Flat Area (in Sqft)'].fillna(df['Flat Area (in Sqft)'].median(), inplace=True)
# /tmp/ipython-input-1025246023.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#              ID Date House was Sold  Sale Price  No of Bedrooms  \
# 586  7942601895      14 August 2017    640000.0               3
# 634  9550204515   14 September 2017    542000.0               2
# 671  5101405124   14 September 2017    435000.0               4
#
#      No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 586              2.5               2160.0              4000.0           1.5
# 634              1.0                890.0              3060.0           1.0
# 671              2.5               1700.0              6380.0           1.0
#
#     Waterfront View Condition of the House  Overall Grade  \
# 586              No                   Fair              8
# 634              No                   Fair              7
# 671              No                   Good              7
#
#      Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 586                                     1960.0                      200
# ...

# %%
df.dropna(subset=['Zipcode','Latitude','Longitude'], inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %% [markdown]
# # Outlier Removal
# * Perform an outlier detection analysis on numerical variables (e.g., using the IQR method).
# * Remove outliers from these features if they are not representative of typical house prices.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21606 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21606 non-null  int64
#  1   Date House was Sold                        21606 non-null  object
#  2   Sale Price                                 21606 non-null  float64
#  3   No of Bedrooms                             21606 non-null  int64
#  4   No of Bathrooms                            21606 non-null  float64
#  5   Flat Area (in Sqft)                        21606 non-null  float64
#  6   Lot Area (in Sqft)                         21606 non-null  float64
#  7   No of Floors                               21606 non-null  float64
#  8   Waterfront View                            21606 non-null  object
#  9   Condition of the House                     21606 non-null  object
# ...

# %%
df.drop(columns=['ID','Date House was Sold', 'Renovated Year', 'Lot Area (in Sqft)'], inplace=True)

# %%
df['No of Bathrooms'] = df['No of Bathrooms'].astype(int)
df['No of Floors'] = df['No of Floors'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21606 entries, 0 to 21612
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Sale Price                                 21606 non-null  float64
#  1   No of Bedrooms                             21606 non-null  int64
#  2   No of Bathrooms                            21606 non-null  int64
#  3   Flat Area (in Sqft)                        21606 non-null  float64
#  4   No of Floors                               21606 non-null  int64
#  5   Waterfront View                            21606 non-null  object
#  6   Condition of the House                     21606 non-null  object
#  7   Overall Grade                              21606 non-null  int64
#  8   Area of the House from Basement (in Sqft)  21606 non-null  float64
#  9   Basement Area (in Sqft)                    21606 non-null  int64
# ...

# %%
fig, ax = plt.subplots(4, 4, figsize = (14, 10))



ax[0,0].boxplot(x = df['Sale Price'])
ax[0,0].set_title("Sale Price")

ax[0,1].boxplot(x = df['No of Bedrooms'])
ax[0,1].set_title('No of Bedrooms')

ax[0,2].boxplot(x = df['No of Bathrooms'])
ax[0,2].set_title('No of Bathrooms')

ax[0,3].boxplot(x = df['Flat Area (in Sqft)'])
ax[0,3].set_title('Flat Area (in Sqft)')

ax[1,0].boxplot(x = df['No of Floors'])
ax[1,0].set_title('No of Floors')

ax[1,1].boxplot(x = df['Overall Grade'])
ax[1,1].set_title('Overall Grade')

ax[1,2].boxplot(x = df['Area of the House from Basement (in Sqft)'])
ax[1,2].set_title('Area of the House from Basement (in Sqft)')

ax[1,3].boxplot(x = df['Basement Area (in Sqft)'])
ax[1,3].set_title('Basement Area (in Sqft)')

ax[2,0].boxplot(x = df['Age of House (in Years)'])
ax[2,0].set_title('Age of House (in Years)')

ax[2,1].boxplot(x = df['Zipcode'])
ax[2,1].set_title('Zipcode')

ax[2,2].boxplot(x = df['Latitude'])
ax[2,2].set_title('Latitude')

ax[2,3].boxplot(x = df['Longitude'])
ax[2,3].set_title('Longitude')

ax[3,0].boxplot(x = df['Living Area after Renovation (in Sqft)'])
ax[3,0].set_title('Living Area after Renovation')

ax[3,1].boxplot(x = df['Lot Area after Renovation (in Sqft)'])
ax[3,1].set_title('Lot Area after Renovation (in Sqft)')


plt.show()

# %%
Q1 = df['Sale Price'].quantile(0.25)
Q3 = df['Sale Price'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['Sale Price'] = df['Sale Price'].clip(low_limit, up_limit)

# %%
Q1 = df['No of Bedrooms'].quantile(0.25)
Q3 = df['No of Bedrooms'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['No of Bedrooms'] = df['No of Bedrooms'].clip(low_limit, up_limit)

# %%
Q1 = df['No of Bathrooms'].quantile(0.25)
Q3 = df['No of Bathrooms'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['No of Bathrooms'] = df['No of Bathrooms'].clip(low_limit, up_limit)

# %%
Q1 = df['Flat Area (in Sqft)'].quantile(0.25)
Q3 = df['Flat Area (in Sqft)'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['Flat Area (in Sqft)'] = df['Flat Area (in Sqft)'].clip(low_limit, up_limit)

# %%
Q1 = df['Overall Grade'].quantile(0.25)
Q3 = df['Overall Grade'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['Overall Grade'] = df['Overall Grade'].clip(low_limit, up_limit)

# %%
Q1 = df['Area of the House from Basement (in Sqft)'].quantile(0.25)
Q3 = df['Area of the House from Basement (in Sqft)'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['Area of the House from Basement (in Sqft)'] = df['Area of the House from Basement (in Sqft)'].clip(low_limit, up_limit)

# %%
Q1 = df['Basement Area (in Sqft)'].quantile(0.25)
Q3 = df['Basement Area (in Sqft)'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['Basement Area (in Sqft)'] = df['Basement Area (in Sqft)'].clip(low_limit, up_limit)

# %%
Q1 = df['Latitude'].quantile(0.25)
Q3 = df['Latitude'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['Latitude'] = df['Latitude'].clip(low_limit, up_limit)

# %%
Q1 = df['Longitude'].quantile(0.25)
Q3 = df['Longitude'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['Longitude'] = df['Longitude'].clip(low_limit, up_limit)

# %%
Q1 = df['Living Area after Renovation (in Sqft)'].quantile(0.25)
Q3 = df['Living Area after Renovation (in Sqft)'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['Living Area after Renovation (in Sqft)'] = df['Living Area after Renovation (in Sqft)'].clip(low_limit, up_limit)

# %%
Q1 = df['Lot Area after Renovation (in Sqft)'].quantile(0.25)
Q3 = df['Lot Area after Renovation (in Sqft)'].quantile(0.75)

IQR = Q3 - Q1
low_limit = Q1 - 1.5 * IQR
up_limit = Q3 + 1.5 * IQR

df['Lot Area after Renovation (in Sqft)'] = df['Lot Area after Renovation (in Sqft)'].clip(low_limit, up_limit)

# %%
fig, ax = plt.subplots(4, 4, figsize = (14, 10))



ax[0,0].boxplot(x = df['Sale Price'])
ax[0,0].set_title("Sale Price")

ax[0,1].boxplot(x = df['No of Bedrooms'])
ax[0,1].set_title('No of Bedrooms')

ax[0,2].boxplot(x = df['No of Bathrooms'])
ax[0,2].set_title('No of Bathrooms')

ax[0,3].boxplot(x = df['Flat Area (in Sqft)'])
ax[0,3].set_title('Flat Area (in Sqft)')

ax[1,0].boxplot(x = df['No of Floors'])
ax[1,0].set_title('No of Floors')

ax[1,1].boxplot(x = df['Overall Grade'])
ax[1,1].set_title('Overall Grade')

ax[1,2].boxplot(x = df['Area of the House from Basement (in Sqft)'])
ax[1,2].set_title('Area of the House from Basement (in Sqft)')

ax[1,3].boxplot(x = df['Basement Area (in Sqft)'])
ax[1,3].set_title('Basement Area (in Sqft)')

ax[2,0].boxplot(x = df['Age of House (in Years)'])
ax[2,0].set_title('Age of House (in Years)')

ax[2,1].boxplot(x = df['Zipcode'])
ax[2,1].set_title('Zipcode')

ax[2,2].boxplot(x = df['Latitude'])
ax[2,2].set_title('Latitude')

ax[2,3].boxplot(x = df['Longitude'])
ax[2,3].set_title('Longitude')

ax[3,0].boxplot(x = df['Living Area after Renovation (in Sqft)'])
ax[3,0].set_title('Living Area after Renovation')

ax[3,1].boxplot(x = df['Lot Area after Renovation (in Sqft)'])
ax[3,1].set_title('Lot Area after Renovation (in Sqft)')


plt.show()

# %% [markdown]
# # Encoding Categorical Variables
# * Identify all categorical columns in the dataset.
# * Apply appropriate encoding techniques:
#   * Use One-Hot Encoding for nominal categories.
#   * Use Label Encoding for ordinal categories, if applicable.

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21606 entries, 0 to 21612
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Sale Price                                 21606 non-null  float64
#  1   No of Bedrooms                             21606 non-null  float64
#  2   No of Bathrooms                            21606 non-null  float64
#  3   Flat Area (in Sqft)                        21606 non-null  float64
#  4   No of Floors                               21606 non-null  int64
#  5   Waterfront View                            21606 non-null  object
#  6   Condition of the House                     21606 non-null  object
#  7   Overall Grade                              21606 non-null  float64
#  8   Area of the House from Basement (in Sqft)  21606 non-null  float64
#  9   Basement Area (in Sqft)                    21606 non-null  int64
# ...

# %%
df['Waterfront View'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
df['Zipcode'].unique()
# Out:
# array([98178., 98125., 98028., 98136., 98074., 98053., 98003., 98198.,
#        98146., 98038., 98007., 98115., 98107., 98126., 98019., 98103.,
#        98002., 98133., 98040., 98092., 98030., 98119., 98112., 98052.,
#        98027., 98117., 98058., 98001., 98056., 98166., 98023., 98070.,
#        98148., 98105., 98042., 98008., 98059., 98122., 98144., 98004.,
#        98005., 98034., 98075., 98116., 98010., 98118., 98199., 98032.,
#        98045., 98102., 98077., 98108., 98168., 98177., 98065., 98029.,
#        98006., 98109., 98022., 98033., 98155., 98024., 98011., 98031.,
#        98106., 98072., 98188., 98014., 98055., 98039.])

# %%
df.drop(columns=['Zipcode'], inplace=True)

# %%
Condition_of_House = ['Bad', 'Fair', 'Okay', 'Good', 'Excellent']
ord_enc = OrdinalEncoder(categories=[Condition_of_House])
df['Condition of the House'] = ord_enc.fit_transform(df[['Condition of the House']])

# %%
df_encode = pd.get_dummies(df, columns=['Waterfront View'], dtype=int, prefix= 'WV', drop_first=True)

# %%
df_encode.head()
# Out:
#    Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0             3.0              1.0               1180.0
# 1    538000.0             3.0              2.0               2570.0
# 2    180000.0             2.0              1.0                770.0
# 3    604000.0             4.0              3.0               1960.0
# 4    510000.0             3.0              2.0               1680.0
#
#    No of Floors  Condition of the House  Overall Grade  \
# 0             1                     1.0            7.0
# 1             2                     1.0            7.0
# 2             1                     1.0            6.0
# 3             1                     4.0            7.0
# 4             1                     1.0            8.0
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# 1                                     2170.0                      400
# ...

# %% [markdown]
# # Scaling Numerical Variables
# * Identify all numerical columns (excluding the target variable SalePrice).
# * Scale these features using techniques like Min-Max scaling or Standard scaling.

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
desired_columns = ['Flat Area (in Sqft)', 'Area of the House from Basement (in Sqft)','Living Area after Renovation (in Sqft)',\
                   'Age of House (in Years)','Lot Area after Renovation (in Sqft)','Latitude','Longitude',\
                   'Basement Area (in Sqft)']

# Plot histograms for selected columns
df_encode[desired_columns].hist(bins=30, figsize=(12, 6), edgecolor='black')
plt.tight_layout()
plt.show()

# %%
min_max_scale = MinMaxScaler(feature_range=(0,1))

# %%
df_encode['Flat Area (in Sqft)'] = min_max_scale.fit_transform(df_encode[['Flat Area (in Sqft)']])

# %%
df_encode['Area of the House from Basement (in Sqft)'] = min_max_scale.fit_transform(df_encode[['Area of the House from Basement (in Sqft)']])

# %%
df_encode['Living Area after Renovation (in Sqft)'] = min_max_scale.fit_transform(df_encode[['Living Area after Renovation (in Sqft)']])

# %%
df_encode['Age of House (in Years)'] = min_max_scale.fit_transform(df_encode[['Age of House (in Years)']])

# %%
df_encode['Lot Area after Renovation (in Sqft)'] = min_max_scale.fit_transform(df_encode[['Lot Area after Renovation (in Sqft)']])

# %%
df_encode['Basement Area (in Sqft)'] = min_max_scale.fit_transform(df_encode[['Basement Area (in Sqft)']])

# %%
df_encode['Latitude'] = min_max_scale.fit_transform(df_encode[['Latitude']])

# %%
df_encode['Longitude'] = min_max_scale.fit_transform(df_encode[['Longitude']])

# %%
df_encode
# Out:
#        Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0        221900.0             3.0              1.0             0.225888
# 1        538000.0             3.0              2.0             0.578680
# 2        180000.0             2.0              1.0             0.121827
# 3        604000.0             4.0              3.0             0.423858
# 4        510000.0             3.0              2.0             0.352792
# ...           ...             ...              ...                  ...
# 21608    360000.0             3.0              2.0             0.314721
# 21609    400000.0             4.0              2.0             0.512690
# 21610    402101.0             2.0              0.0             0.185279
# 21611    400000.0             3.0              2.0             0.332487
# 21612    325000.0             2.0              0.0             0.185279
#
#        No of Floors  Condition of the House  Overall Grade  \
# ...

# %%
df_encode.describe()
# Out:
#          Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# count  2.160600e+04    21606.000000     21606.000000         21606.000000
# mean   5.116418e+05        3.362793         1.736416             0.448729
# std    2.501442e+05        0.853990         0.691315             0.212918
# min    7.500000e+04        1.500000         0.000000             0.000000
# 25%    3.216125e+05        3.000000         1.000000             0.289340
# 50%    4.500000e+05        3.000000         2.000000             0.411168
# 75%    6.450000e+05        4.000000         2.000000             0.573604
# max    1.130081e+06        5.500000         3.500000             1.000000
#
#        No of Floors  Condition of the House  Overall Grade  \
# count  21606.000000            21606.000000   21606.000000
# mean       1.446172                1.768259       7.596246
# std        0.551823                1.085698       1.001586
# min        1.000000                0.000000       5.500000
# ...

# %% [markdown]
# # Train-Test Split
# * Set aside the SalePrice column as the target variable.
# * Split the dataset into training (80%) and testing (20%) sets using the train_test_split function from sklearn.
#
# * Submission: Upload the completed notebook to your GitHub and share the link of the same here.

# %%
from sklearn.model_selection import train_test_split

# %%
x = df_encode.drop(columns=['Sale Price'])
y = df_encode['Sale Price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

print("Shape of x_train", x_train.shape)
print("Shape of y_train", y_train.shape)
print("Shape of x_test", x_test.shape)
print("Shape of y_test", y_test.shape)
# Out:
# Shape of x_train (17284, 14)
# Shape of y_train (17284,)
# Shape of x_test (4322, 14)
# Shape of y_test (4322,)
